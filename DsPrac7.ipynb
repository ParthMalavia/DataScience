# %%
"""
DS Practical 7: Web scraping

Enrollment: 180280116047
"""
# Out:
# '\nDS Practical 7: Web scraping\n\nEnrollment: 180280116047\n'

# %%
import requests 
from bs4 import BeautifulSoup 
import csv

# %%
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 

quotes=[] # a list to store quotes 

table = soup.find('div', attrs = {'id':'all_quotes'})

# %%
for row in table.findAll('div', 
                         {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}): 
	quote = {} 
	quote['theme'] = row.h5.text 
	quote['lines'] = row.img['alt'].split(" #")[0] 
	quote['url'] = row.a['href'] 
	quote['img'] = row.img['src']  
	quotes.append(quote)

# %%
#writing quote data in file
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='') as f: 
	w = csv.DictWriter(f,['theme','lines','url','img']) 
	w.writeheader() 
	for quote in quotes: 
		w.writerow(quote)

# %%
#reading file data
import pandas as pd

dataset = pd.read_csv("inspirational_quotes.csv")
dataset
# Out:
#                   theme  ...                                                img
# 0              CIVILITY  ...  https://assets.passiton.com/quotes/quote_artwo...
# 1              CIVILITY  ...  https://assets.passiton.com/quotes/quote_artwo...
# 2              CIVILITY  ...  https://assets.passiton.com/quotes/quote_artwo...
# 3              CIVILITY  ...  https://assets.passiton.com/quotes/quote_artwo...
# 4              CIVILITY  ...  https://assets.passiton.com/quotes/quote_artwo...
# 5   MAKING A DIFFERENCE  ...  https://assets.passiton.com/quotes/quote_artwo...
# 6   MAKING A DIFFERENCE  ...  https://assets.passiton.com/quotes/quote_artwo...
# 7   MAKING A DIFFERENCE  ...  https://assets.passiton.com/quotes/quote_artwo...
# 8   MAKING A DIFFERENCE  ...  https://assets.passiton.com/quotes/quote_artwo...
# 9   MAKING A DIFFERENCE  ...  https://assets.passiton.com/quotes/quote_artwo...
# 10            HARD WORK  ...  https://assets.passiton.com/quotes/quote_artwo...
# ...
